# %% [markdown]
# ## Use pandas to extract files from online

# %%
import pandas as pd

# %%
simpsons = pd.read_html("https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes")
print(simpsons[1])
# Out:
#                    Title      Directed by  \
# 0    The Longest Daycare  David Silverman
# 1  Playdate with Destiny  David Silverman
#
#                                           Written by Original release date
# 0  James L. Brooks, Matt Groening, Al Jean, David...         July 13, 2012
# 1  Al Jean, Tom Gammill, Max Pross, James L. Broo...         March 6, 2020

# %%
len(simpsons)
# Out:
# 15

# %%
premier_league_24 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E0.csv')
print(premier_league_24.head())
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0     0
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A     0     0
# 2  E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1     0
# 3  E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0     1
# 4  E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1     0
#
#    ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0  ...     1.86     2.07   1.83   2.11     1.88     2.11     1.82     2.05
# 1  ...     2.05     1.88   2.04   1.90     2.20     2.00     1.99     1.88
# 2  ...     2.02     1.91   2.00   1.90     2.05     1.93     1.99     1.87
# 3  ...     1.87     2.06   1.86   2.07     1.92     2.10     1.83     2.04
# 4  ...     1.87     2.06   1.88   2.06     1.89     2.10     1.82     2.05
#
#    BFECAHH  BFECAHA
# 0     1.90     2.08
# ...

# %%
premier_league_24.rename(columns={'FTHG': 'home_goal',
                                  'FTAG': 'away_goal',})
# Out:
#     Div        Date   Time     HomeTeam     AwayTeam  home_goal  away_goal  \
# 0    E0  16/08/2024  20:00   Man United       Fulham          1          0
# 1    E0  17/08/2024  12:30      Ipswich    Liverpool          0          2
# 2    E0  17/08/2024  15:00      Arsenal       Wolves          2          0
# 3    E0  17/08/2024  15:00      Everton     Brighton          0          3
# 4    E0  17/08/2024  15:00    Newcastle  Southampton          1          0
# ..   ..         ...    ...          ...          ...        ...        ...
# 334  E0  26/04/2025  15:00    Newcastle      Ipswich          3          0
# 335  E0  26/04/2025  15:00  Southampton       Fulham          1          2
# 336  E0  26/04/2025  15:00       Wolves    Leicester          3          0
# 337  E0  27/04/2025  14:00  Bournemouth   Man United          1          1
# 338  E0  27/04/2025  16:30    Liverpool    Tottenham          5          1
#
# ...

# %% [markdown]
# ## Extract table from pdf
# #### Using camelot

# %%
# import camelot

'''
camelot.read_pdf('file_name.pdf', pages='mention_page_number'))

'''
# Out:
# "\ncamelot.read_pdf('file_name.pdf', pages='mention_page_number'))\n\n"

# %%
import selenium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import selenium
#
# ModuleNotFoundError: No module named 'selenium'
